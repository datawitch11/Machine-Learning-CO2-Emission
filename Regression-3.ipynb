# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv('MY2014.csv',encoding ='ISO-8859-1')

# %%
df.head()
# Out:
#   MODEL   MAKE                 MODEL.1 VEHICLE CLASS ENGINE SIZE  CYLINDERS  \
# 0  YEAR    NaN  # = high output engine           NaN         (L)        NaN
# 1  2014  ACURA                     ILX       COMPACT         2.0        4.0
# 2  2014  ACURA                     ILX       COMPACT         2.4        4.0
# 3  2014  ACURA              ILX HYBRID       COMPACT         1.5        4.0
# 4  2014  ACURA                 MDX 4WD   SUV - SMALL         3.5        6.0
#
#   TRANSMISSION  FUEL FUEL CONSUMPTION*      Unnamed: 9  ... Unnamed: 211  \
# 0          NaN  TYPE   CITY (L/100 km)  HWY (L/100 km)  ...          NaN
# 1          AS5     Z               9.9             6.7  ...          NaN
# 2           M6     Z              11.2             7.7  ...          NaN
# 3          AV7     Z               6.0             5.8  ...          NaN
# 4          AS6     Z              12.7             9.1  ...          NaN
#
#   Unnamed: 212 Unnamed: 213  Unnamed: 214  Unnamed: 215  Unnamed: 216  \
# 0          NaN          NaN           NaN           NaN           NaN
# 1          NaN          NaN           NaN           NaN           NaN
# 2          NaN          NaN           NaN           NaN           NaN
# 3          NaN          NaN           NaN           NaN           NaN
# 4          NaN          NaN           NaN           NaN           NaN
#
#    Unnamed: 217  Unnamed: 218  Unnamed: 219  Unnamed: 220
# 0           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN
#
# [5 rows x 221 columns]

# %%
df.drop(df.index[0],inplace=True)
df.dropna(axis=1,how='all',inplace=True)
df.dropna(axis=0,how='any',inplace=True)
df.head()
# Out:
#   MODEL   MAKE     MODEL.1 VEHICLE CLASS ENGINE SIZE  CYLINDERS TRANSMISSION  \
# 1  2014  ACURA         ILX       COMPACT         2.0        4.0          AS5
# 2  2014  ACURA         ILX       COMPACT         2.4        4.0           M6
# 3  2014  ACURA  ILX HYBRID       COMPACT         1.5        4.0          AV7
# 4  2014  ACURA     MDX 4WD   SUV - SMALL         3.5        6.0          AS6
# 5  2014  ACURA     RDX AWD   SUV - SMALL         3.5        6.0          AS6
#
#   FUEL FUEL CONSUMPTION* Unnamed: 9 Unnamed: 10 Unnamed: 11 CO2 EMISSIONS
# 1    Z               9.9        6.7         8.5          33            196
# 2    Z              11.2        7.7         9.6          29            221
# 3    Z               6.0        5.8         5.9          48            136
# 4    Z              12.7        9.1        11.1          25            255
# 5    Z              12.1        8.7        10.6          27            244

# %%
df
# Out:
#      MODEL          MAKE               MODEL.1   VEHICLE CLASS ENGINE SIZE  \
# 1     2014         ACURA                   ILX         COMPACT         2.0
# 2     2014         ACURA                   ILX         COMPACT         2.4
# 3     2014         ACURA            ILX HYBRID         COMPACT         1.5
# 4     2014         ACURA               MDX 4WD     SUV - SMALL         3.5
# 5     2014         ACURA               RDX AWD     SUV - SMALL         3.5
# 6     2014         ACURA                   RLX        MID-SIZE         3.5
# 7     2014         ACURA                    TL        MID-SIZE         3.5
# 8     2014         ACURA                TL AWD        MID-SIZE         3.7
# 9     2014         ACURA                TL AWD        MID-SIZE         3.7
# 10    2014         ACURA                   TSX         COMPACT         2.4
# 11    2014         ACURA                   TSX         COMPACT         2.4
# 12    2014         ACURA                   TSX         COMPACT         3.5
# 13    2014    ALFA ROMEO                    4C      TWO-SEATER         1.8
# 14    2014  ASTON MARTIN                   DB9     MINICOMPACT         5.9
# 15    2014  ASTON MARTIN                RAPIDE      SUBCOMPACT         5.9
# 16    2014  ASTON MARTIN            V8 VANTAGE      TWO-SEATER         4.7
# 17    2014  ASTON MARTIN            V8 VANTAGE      TWO-SEATER         4.7
# 18    2014  ASTON MARTIN          V8 VANTAGE S      TWO-SEATER         4.7
# 19    2014  ASTON MARTIN          V8 VANTAGE S      TWO-SEATER         4.7
# 20    2014  ASTON MARTIN              VANQUISH     MINICOMPACT         5.9
# 21    2014          AUDI                    A4         COMPACT         2.0
# 22    2014          AUDI            A4 QUATTRO         COMPACT         2.0
# 23    2014          AUDI            A4 QUATTRO         COMPACT         2.0
# 24    2014          AUDI  A5 CABRIOLET QUATTRO      SUBCOMPACT         2.0
# 25    2014          AUDI            A5 QUATTRO      SUBCOMPACT         2.0
# 26    2014          AUDI            A5 QUATTRO      SUBCOMPACT         2.0
# 27    2014          AUDI            A6 QUATTRO        MID-SIZE         2.0
# 28    2014          AUDI            A6 QUATTRO        MID-SIZE         3.0
# 29    2014          AUDI        A6 QUATTRO TDI        MID-SIZE         3.0
# 30    2014          AUDI            A7 QUATTRO        MID-SIZE         3.0
# ...    ...           ...                   ...             ...         ...
# 1043  2014    VOLKSWAGEN                 JETTA         COMPACT         2.0
# 1044  2014    VOLKSWAGEN             JETTA GLI         COMPACT         2.0
# 1045  2014    VOLKSWAGEN             JETTA GLI         COMPACT         2.0
# 1046  2014    VOLKSWAGEN             JETTA TDI         COMPACT         2.0
# 1047  2014    VOLKSWAGEN             JETTA TDI         COMPACT         2.0
# 1048  2014    VOLKSWAGEN    JETTA TURBO HYBRID         COMPACT         1.4
# 1049  2014    VOLKSWAGEN                PASSAT        MID-SIZE         1.8
# 1050  2014    VOLKSWAGEN                PASSAT        MID-SIZE         1.8
# 1051  2014    VOLKSWAGEN                PASSAT        MID-SIZE         2.5
# 1052  2014    VOLKSWAGEN                PASSAT        MID-SIZE         2.5
# 1053  2014    VOLKSWAGEN                PASSAT        MID-SIZE         3.6
# 1054  2014    VOLKSWAGEN            PASSAT TDI        MID-SIZE         2.0
# 1055  2014    VOLKSWAGEN            PASSAT TDI        MID-SIZE         2.0
# 1056  2014    VOLKSWAGEN                ROUTAN         MINIVAN         3.6
# 1057  2014    VOLKSWAGEN                TIGUAN     SUV - SMALL         2.0
# 1058  2014    VOLKSWAGEN                TIGUAN     SUV - SMALL         2.0
# 1059  2014    VOLKSWAGEN        TIGUAN 4MOTION     SUV - SMALL         2.0
# 1060  2014    VOLKSWAGEN               TOUAREG  SUV - STANDARD         3.6
# 1061  2014    VOLKSWAGEN           TOUAREG TDI  SUV - STANDARD         3.0
# 1062  2014         VOLVO                   S60         COMPACT         2.5
# 1063  2014         VOLVO               S60 AWD         COMPACT         2.5
# 1064  2014         VOLVO               S60 AWD         COMPACT         3.0
# 1065  2014         VOLVO                   S80        MID-SIZE         3.2
# 1066  2014         VOLVO               S80 AWD        MID-SIZE         3.0
# 1067  2014         VOLVO                  XC60     SUV - SMALL         3.2
# 1068  2014         VOLVO              XC60 AWD     SUV - SMALL         3.0
# 1069  2014         VOLVO              XC60 AWD     SUV - SMALL         3.2
# 1070  2014         VOLVO              XC70 AWD     SUV - SMALL         3.0
# 1071  2014         VOLVO              XC70 AWD     SUV - SMALL         3.2
# 1072  2014         VOLVO              XC90 AWD  SUV - STANDARD         3.2
#
#       CYLINDERS TRANSMISSION FUEL FUEL CONSUMPTION* Unnamed: 9 Unnamed: 10  \
# 1           4.0          AS5    Z               9.9        6.7         8.5
# 2           4.0           M6    Z              11.2        7.7         9.6
# 3           4.0          AV7    Z               6.0        5.8         5.9
# 4           6.0          AS6    Z              12.7        9.1        11.1
# 5           6.0          AS6    Z              12.1        8.7        10.6
# 6           6.0          AS6    Z              11.9        7.7        10.0
# 7           6.0          AS6    Z              11.8        8.1        10.1
# 8           6.0          AS6    Z              12.8        9.0        11.1
# 9           6.0           M6    Z              13.4        9.5        11.6
# 10          4.0          AS5    Z              10.6        7.5         9.2
# 11          4.0           M6    Z              11.2        8.1         9.8
# 12          6.0          AS5    Z              12.1        8.3        10.4
# 13          4.0          AM6    Z               9.7        6.9         8.4
# 14         12.0           A6    Z              18.0       12.6        15.6
# 15         12.0           A6    Z              18.0       12.6        15.6
# 16          8.0          AM7    Z              17.4       11.3        14.7
# 17          8.0           M6    Z              18.1       12.2        15.4
# 18          8.0          AM7    Z              17.4       11.3        14.7
# 19          8.0           M6    Z              18.1       12.2        15.4
# 20         12.0           A6    Z              18.0       12.6        15.6
# 21          4.0          AV8    Z               9.9        7.4         8.8
# 22          4.0          AS8    Z              11.5        8.1        10.0
# 23          4.0           M6    Z              10.8        7.5         9.3
# 24          4.0          AS8    Z              11.5        8.1        10.0
# 25          4.0          AS8    Z              11.5        8.1        10.0
# 26          4.0           M6    Z              10.8        7.5         9.3
# 27          4.0          AS8    Z              12.0        8.1        10.2
# 28          6.0          AS8    Z              12.8        8.6        10.9
# 29          6.0          AS8    D               9.8        6.4         8.3
# 30          6.0          AS8    Z              13.1        8.8        11.2
# ...         ...          ...  ...               ...        ...         ...
# 1043        4.0           M5    X              10.4        7.2         9.0
# 1044        4.0           A6    Z              10.2        7.5         9.0
# 1045        4.0           M6    Z              10.6        7.4         9.2
# 1046        4.0           A6    D               7.9        5.7         6.9
# 1047        4.0           M6    D               7.9        5.6         6.9
# 1048        4.0          AM7    Z               5.6        5.2         5.4
# 1049        4.0           A6    X               9.9        6.9         8.6
# 1050        4.0           M5    X              10.0        6.9         8.6
# 1051        5.0           A6    X              11.0        8.0         9.7
# 1052        5.0           M5    X              11.4        7.8         9.8
# 1053        6.0           A6    Z              12.4        8.8        10.8
# 1054        4.0           A6    D               8.1        5.9         7.1
# 1055        4.0           M6    D               8.0        5.4         6.8
# 1056        6.0           A6    X              14.2        9.5        12.1
# 1057        4.0           A6    Z              11.7        9.5        10.7
# 1058        4.0           M6    Z              13.6        9.2        11.6
# 1059        4.0           A6    Z              11.7        9.4        10.7
# 1060        6.0          AS8    Z              13.8       10.3        12.2
# 1061        6.0          AS8    D              12.3        8.0        10.4
# 1062        5.0          AS6    X              11.3        7.8         9.7
# 1063        5.0          AS6    X              11.6        8.3        10.1
# 1064        6.0          AS6    X              13.2        9.5        11.5
# 1065        6.0          AS6    X              11.9        8.1        10.2
# 1066        6.0          AS6    X              13.2        9.5        11.5
# 1067        6.0          AS6    X              13.0        8.9        11.2
# 1068        6.0          AS6    X              13.4        9.8        11.8
# 1069        6.0          AS6    X              13.2        9.5        11.5
# 1070        6.0          AS6    X              13.4        9.8        11.8
# 1071        6.0          AS6    X              12.9        9.3        11.3
# 1072        6.0          AS6    X              14.9       10.2        12.8
#
#      Unnamed: 11 CO2 EMISSIONS
# 1             33            196
# 2             29            221
# 3             48            136
# 4             25            255
# 5             27            244
# 6             28            230
# 7             28            232
# 8             25            255
# 9             24            267
# 10            31            212
# 11            29            225
# 12            27            239
# 13            34            193
# 14            18            359
# 15            18            359
# 16            19            338
# 17            18            354
# 18            19            338
# 19            18            354
# 20            18            359
# 21            32            202
# 22            28            230
# 23            30            214
# 24            28            230
# 25            28            230
# 26            30            214
# 27            28            235
# 28            26            251
# 29            34            224
# 30            25            258
# ...          ...            ...
# 1043          31            207
# 1044          31            207
# 1045          31            212
# 1046          41            186
# 1047          41            186
# 1048          52            124
# 1049          33            198
# 1050          33            198
# 1051          29            223
# 1052          29            225
# 1053          26            248
# 1054          40            192
# 1055          42            184
# 1056          23            278
# 1057          26            246
# 1058          24            267
# 1059          26            246
# 1060          23            281
# 1061          27            281
# 1062          29            223
# 1063          28            232
# 1064          25            264
# 1065          28            235
# 1066          25            264
# 1067          25            258
# 1068          24            271
# 1069          25            264
# 1070          24            271
# 1071          25            260
# 1072          22            294
#
# [1072 rows x 13 columns]

# %%
df.describe()
# Out:
#          CYLINDERS
# count  1072.000000
# mean      5.786381
# std       1.797415
# min       3.000000
# 25%       4.000000
# 50%       6.000000
# 75%       8.000000
# max      12.000000

# %%
df.columns = ['MODEL', 'MAKE', 'MODEL.1', 'VEHICLE CLASS', 'ENGINESIZE', 'CYLINDERS', 'TRANSMISSION', 'FUEL', 'FUELConscityLper100km','HWYLper100km','COMbLper100km','Combpermpg','CO2Emission']

# %%
print ("Rows     : " ,df.shape[0])
print ("Columns  : " ,df.shape[1])
print ("\nFeatures : \n" ,df.columns.tolist())
print ("\nMissing values :  ", df.isnull().sum().values.sum())
print ("\nUnique values :  \n",df.nunique())
# Out:
# Rows     :  1072
# Columns  :  13
#
# Features :
#  ['MODEL', 'MAKE', 'MODEL.1', 'VEHICLE CLASS', 'ENGINESIZE', 'CYLINDERS', 'TRANSMISSION', 'FUEL', 'FUELConscityLper100km', 'HWYLper100km', 'COMbLper100km', 'Combpermpg', 'CO2Emission']
#
# Missing values :   0
#
# Unique values :
#  MODEL                      1
# MAKE                      40
# MODEL.1                  666
# VEHICLE CLASS             16
# ENGINESIZE                45
# CYLINDERS                  7
# TRANSMISSION              22
# FUEL                       4
# FUELConscityLper100km    168
# HWYLper100km             118
# COMbLper100km            148
# Combpermpg                43
# CO2Emission              159
# dtype: int64

# %%
df.head()
# Out:
#   MODEL   MAKE     MODEL.1 VEHICLE CLASS ENGINESIZE  CYLINDERS TRANSMISSION  \
# 1  2014  ACURA         ILX       COMPACT        2.0        4.0          AS5
# 2  2014  ACURA         ILX       COMPACT        2.4        4.0           M6
# 3  2014  ACURA  ILX HYBRID       COMPACT        1.5        4.0          AV7
# 4  2014  ACURA     MDX 4WD   SUV - SMALL        3.5        6.0          AS6
# 5  2014  ACURA     RDX AWD   SUV - SMALL        3.5        6.0          AS6
#
#   FUEL FUELConscityLper100km HWYLper100km COMbLper100km Combpermpg CO2Emission
# 1    Z                   9.9          6.7           8.5         33         196
# 2    Z                  11.2          7.7           9.6         29         221
# 3    Z                   6.0          5.8           5.9         48         136
# 4    Z                  12.7          9.1          11.1         25         255
# 5    Z                  12.1          8.7          10.6         27         244

# %%
cdf = df[['ENGINESIZE','CYLINDERS', 'COMbLper100km','CO2Emission']]
df.dropna(axis=0,how='all',inplace=True)
cdf = cdf.astype(np.float)

# %%
cdf.head()
# Out:
#    ENGINESIZE  CYLINDERS  COMbLper100km  CO2Emission
# 1         2.0        4.0            8.5        196.0
# 2         2.4        4.0            9.6        221.0
# 3         1.5        4.0            5.9        136.0
# 4         3.5        6.0           11.1        255.0
# 5         3.5        6.0           10.6        244.0

# %%
viz = cdf[['CYLINDERS','ENGINESIZE','CO2Emission','COMbLper100km']]
viz.hist()
plt.show()

# %%
plt.scatter(cdf.COMbLper100km, cdf.CO2Emission,  color='blue')
plt.xlabel("FUELCONSUMPTION_COMB L/100km")
plt.ylabel("CO2 Emission")
plt.show()

# %%
plt.scatter(cdf.ENGINESIZE, cdf.CO2Emission,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("CO2 Emission")
plt.show()

# %%
plt.scatter(cdf.CYLINDERS, cdf.CO2Emission,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("CO2 Emission")
plt.show()

# %%
msk = np.random.rand(len(cdf)) < 0.8
np.where(np.isnan(cdf))

train = cdf[msk]
test = cdf[~msk]
col_mask=cdf.isnull().any(axis=0)

# %%
plt.scatter(train.ENGINESIZE, train.CO2Emission,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("CO2 Emission")
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(train[['ENGINESIZE']])
train_y = np.asanyarray(train[['CO2Emission']])
regr.fit (train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[39.92369906]]
# Intercept:  [122.89482189]

# %%
plt.scatter(train.ENGINESIZE, train.CO2Emission,  color='blue')
plt.plot(train_x, regr.coef_[0][0]*train_x + regr.intercept_[0], '-r')
plt.xlabel("Engine size")
plt.ylabel("Emission")
# Out:
# Text(0, 0.5, 'Emission')

# %%
from sklearn.metrics import r2_score

test_x = np.asanyarray(test[['ENGINESIZE']])
test_y = np.asanyarray(test[['CO2Emission']])
test_y_hat = regr.predict(test_x)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_hat - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_hat - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y_hat , test_y) )
# Out:
# Mean absolute error: 23.24
# Residual sum of squares (MSE): 925.33
# R2-score: 0.71

# %%
df
# Out:
#      MODEL          MAKE               MODEL.1   VEHICLE CLASS ENGINESIZE  \
# 1     2014         ACURA                   ILX         COMPACT        2.0
# 2     2014         ACURA                   ILX         COMPACT        2.4
# 3     2014         ACURA            ILX HYBRID         COMPACT        1.5
# 4     2014         ACURA               MDX 4WD     SUV - SMALL        3.5
# 5     2014         ACURA               RDX AWD     SUV - SMALL        3.5
# 6     2014         ACURA                   RLX        MID-SIZE        3.5
# 7     2014         ACURA                    TL        MID-SIZE        3.5
# 8     2014         ACURA                TL AWD        MID-SIZE        3.7
# 9     2014         ACURA                TL AWD        MID-SIZE        3.7
# 10    2014         ACURA                   TSX         COMPACT        2.4
# 11    2014         ACURA                   TSX         COMPACT        2.4
# 12    2014         ACURA                   TSX         COMPACT        3.5
# 13    2014    ALFA ROMEO                    4C      TWO-SEATER        1.8
# 14    2014  ASTON MARTIN                   DB9     MINICOMPACT        5.9
# 15    2014  ASTON MARTIN                RAPIDE      SUBCOMPACT        5.9
# 16    2014  ASTON MARTIN            V8 VANTAGE      TWO-SEATER        4.7
# 17    2014  ASTON MARTIN            V8 VANTAGE      TWO-SEATER        4.7
# 18    2014  ASTON MARTIN          V8 VANTAGE S      TWO-SEATER        4.7
# 19    2014  ASTON MARTIN          V8 VANTAGE S      TWO-SEATER        4.7
# 20    2014  ASTON MARTIN              VANQUISH     MINICOMPACT        5.9
# 21    2014          AUDI                    A4         COMPACT        2.0
# 22    2014          AUDI            A4 QUATTRO         COMPACT        2.0
# 23    2014          AUDI            A4 QUATTRO         COMPACT        2.0
# 24    2014          AUDI  A5 CABRIOLET QUATTRO      SUBCOMPACT        2.0
# 25    2014          AUDI            A5 QUATTRO      SUBCOMPACT        2.0
# 26    2014          AUDI            A5 QUATTRO      SUBCOMPACT        2.0
# 27    2014          AUDI            A6 QUATTRO        MID-SIZE        2.0
# 28    2014          AUDI            A6 QUATTRO        MID-SIZE        3.0
# 29    2014          AUDI        A6 QUATTRO TDI        MID-SIZE        3.0
# 30    2014          AUDI            A7 QUATTRO        MID-SIZE        3.0
# ...    ...           ...                   ...             ...        ...
# 1043  2014    VOLKSWAGEN                 JETTA         COMPACT        2.0
# 1044  2014    VOLKSWAGEN             JETTA GLI         COMPACT        2.0
# 1045  2014    VOLKSWAGEN             JETTA GLI         COMPACT        2.0
# 1046  2014    VOLKSWAGEN             JETTA TDI         COMPACT        2.0
# 1047  2014    VOLKSWAGEN             JETTA TDI         COMPACT        2.0
# 1048  2014    VOLKSWAGEN    JETTA TURBO HYBRID         COMPACT        1.4
# 1049  2014    VOLKSWAGEN                PASSAT        MID-SIZE        1.8
# 1050  2014    VOLKSWAGEN                PASSAT        MID-SIZE        1.8
# 1051  2014    VOLKSWAGEN                PASSAT        MID-SIZE        2.5
# 1052  2014    VOLKSWAGEN                PASSAT        MID-SIZE        2.5
# 1053  2014    VOLKSWAGEN                PASSAT        MID-SIZE        3.6
# 1054  2014    VOLKSWAGEN            PASSAT TDI        MID-SIZE        2.0
# 1055  2014    VOLKSWAGEN            PASSAT TDI        MID-SIZE        2.0
# 1056  2014    VOLKSWAGEN                ROUTAN         MINIVAN        3.6
# 1057  2014    VOLKSWAGEN                TIGUAN     SUV - SMALL        2.0
# 1058  2014    VOLKSWAGEN                TIGUAN     SUV - SMALL        2.0
# 1059  2014    VOLKSWAGEN        TIGUAN 4MOTION     SUV - SMALL        2.0
# 1060  2014    VOLKSWAGEN               TOUAREG  SUV - STANDARD        3.6
# 1061  2014    VOLKSWAGEN           TOUAREG TDI  SUV - STANDARD        3.0
# 1062  2014         VOLVO                   S60         COMPACT        2.5
# 1063  2014         VOLVO               S60 AWD         COMPACT        2.5
# 1064  2014         VOLVO               S60 AWD         COMPACT        3.0
# 1065  2014         VOLVO                   S80        MID-SIZE        3.2
# 1066  2014         VOLVO               S80 AWD        MID-SIZE        3.0
# 1067  2014         VOLVO                  XC60     SUV - SMALL        3.2
# 1068  2014         VOLVO              XC60 AWD     SUV - SMALL        3.0
# 1069  2014         VOLVO              XC60 AWD     SUV - SMALL        3.2
# 1070  2014         VOLVO              XC70 AWD     SUV - SMALL        3.0
# 1071  2014         VOLVO              XC70 AWD     SUV - SMALL        3.2
# 1072  2014         VOLVO              XC90 AWD  SUV - STANDARD        3.2
#
#       CYLINDERS TRANSMISSION FUEL FUELConscityLper100km HWYLper100km  \
# 1           4.0          AS5    Z                   9.9          6.7
# 2           4.0           M6    Z                  11.2          7.7
# 3           4.0          AV7    Z                   6.0          5.8
# 4           6.0          AS6    Z                  12.7          9.1
# 5           6.0          AS6    Z                  12.1          8.7
# 6           6.0          AS6    Z                  11.9          7.7
# 7           6.0          AS6    Z                  11.8          8.1
# 8           6.0          AS6    Z                  12.8          9.0
# 9           6.0           M6    Z                  13.4          9.5
# 10          4.0          AS5    Z                  10.6          7.5
# 11          4.0           M6    Z                  11.2          8.1
# 12          6.0          AS5    Z                  12.1          8.3
# 13          4.0          AM6    Z                   9.7          6.9
# 14         12.0           A6    Z                  18.0         12.6
# 15         12.0           A6    Z                  18.0         12.6
# 16          8.0          AM7    Z                  17.4         11.3
# 17          8.0           M6    Z                  18.1         12.2
# 18          8.0          AM7    Z                  17.4         11.3
# 19          8.0           M6    Z                  18.1         12.2
# 20         12.0           A6    Z                  18.0         12.6
# 21          4.0          AV8    Z                   9.9          7.4
# 22          4.0          AS8    Z                  11.5          8.1
# 23          4.0           M6    Z                  10.8          7.5
# 24          4.0          AS8    Z                  11.5          8.1
# 25          4.0          AS8    Z                  11.5          8.1
# 26          4.0           M6    Z                  10.8          7.5
# 27          4.0          AS8    Z                  12.0          8.1
# 28          6.0          AS8    Z                  12.8          8.6
# 29          6.0          AS8    D                   9.8          6.4
# 30          6.0          AS8    Z                  13.1          8.8
# ...         ...          ...  ...                   ...          ...
# 1043        4.0           M5    X                  10.4          7.2
# 1044        4.0           A6    Z                  10.2          7.5
# 1045        4.0           M6    Z                  10.6          7.4
# 1046        4.0           A6    D                   7.9          5.7
# 1047        4.0           M6    D                   7.9          5.6
# 1048        4.0          AM7    Z                   5.6          5.2
# 1049        4.0           A6    X                   9.9          6.9
# 1050        4.0           M5    X                  10.0          6.9
# 1051        5.0           A6    X                  11.0          8.0
# 1052        5.0           M5    X                  11.4          7.8
# 1053        6.0           A6    Z                  12.4          8.8
# 1054        4.0           A6    D                   8.1          5.9
# 1055        4.0           M6    D                   8.0          5.4
# 1056        6.0           A6    X                  14.2          9.5
# 1057        4.0           A6    Z                  11.7          9.5
# 1058        4.0           M6    Z                  13.6          9.2
# 1059        4.0           A6    Z                  11.7          9.4
# 1060        6.0          AS8    Z                  13.8         10.3
# 1061        6.0          AS8    D                  12.3          8.0
# 1062        5.0          AS6    X                  11.3          7.8
# 1063        5.0          AS6    X                  11.6          8.3
# 1064        6.0          AS6    X                  13.2          9.5
# 1065        6.0          AS6    X                  11.9          8.1
# 1066        6.0          AS6    X                  13.2          9.5
# 1067        6.0          AS6    X                  13.0          8.9
# 1068        6.0          AS6    X                  13.4          9.8
# 1069        6.0          AS6    X                  13.2          9.5
# 1070        6.0          AS6    X                  13.4          9.8
# 1071        6.0          AS6    X                  12.9          9.3
# 1072        6.0          AS6    X                  14.9         10.2
#
#      COMbLper100km Combpermpg CO2Emission
# 1              8.5         33         196
# 2              9.6         29         221
# 3              5.9         48         136
# 4             11.1         25         255
# 5             10.6         27         244
# 6             10.0         28         230
# 7             10.1         28         232
# 8             11.1         25         255
# 9             11.6         24         267
# 10             9.2         31         212
# 11             9.8         29         225
# 12            10.4         27         239
# 13             8.4         34         193
# 14            15.6         18         359
# 15            15.6         18         359
# 16            14.7         19         338
# 17            15.4         18         354
# 18            14.7         19         338
# 19            15.4         18         354
# 20            15.6         18         359
# 21             8.8         32         202
# 22            10.0         28         230
# 23             9.3         30         214
# 24            10.0         28         230
# 25            10.0         28         230
# 26             9.3         30         214
# 27            10.2         28         235
# 28            10.9         26         251
# 29             8.3         34         224
# 30            11.2         25         258
# ...            ...        ...         ...
# 1043           9.0         31         207
# 1044           9.0         31         207
# 1045           9.2         31         212
# 1046           6.9         41         186
# 1047           6.9         41         186
# 1048           5.4         52         124
# 1049           8.6         33         198
# 1050           8.6         33         198
# 1051           9.7         29         223
# 1052           9.8         29         225
# 1053          10.8         26         248
# 1054           7.1         40         192
# 1055           6.8         42         184
# 1056          12.1         23         278
# 1057          10.7         26         246
# 1058          11.6         24         267
# 1059          10.7         26         246
# 1060          12.2         23         281
# 1061          10.4         27         281
# 1062           9.7         29         223
# 1063          10.1         28         232
# 1064          11.5         25         264
# 1065          10.2         28         235
# 1066          11.5         25         264
# 1067          11.2         25         258
# 1068          11.8         24         271
# 1069          11.5         25         264
# 1070          11.8         24         271
# 1071          11.3         25         260
# 1072          12.8         22         294
#
# [1072 rows x 13 columns]

# %%
cdf1 = df[['ENGINESIZE','CYLINDERS','FUELConscityLper100km','HWYLper100km','COMbLper100km','CO2Emission']]

# %%
cdf
# Out:
#       ENGINESIZE  CYLINDERS  COMbLper100km  CO2Emission
# 1            2.0        4.0            8.5        196.0
# 2            2.4        4.0            9.6        221.0
# 3            1.5        4.0            5.9        136.0
# 4            3.5        6.0           11.1        255.0
# 5            3.5        6.0           10.6        244.0
# 6            3.5        6.0           10.0        230.0
# 7            3.5        6.0           10.1        232.0
# 8            3.7        6.0           11.1        255.0
# 9            3.7        6.0           11.6        267.0
# 10           2.4        4.0            9.2        212.0
# 11           2.4        4.0            9.8        225.0
# 12           3.5        6.0           10.4        239.0
# 13           1.8        4.0            8.4        193.0
# 14           5.9       12.0           15.6        359.0
# 15           5.9       12.0           15.6        359.0
# 16           4.7        8.0           14.7        338.0
# 17           4.7        8.0           15.4        354.0
# 18           4.7        8.0           14.7        338.0
# 19           4.7        8.0           15.4        354.0
# 20           5.9       12.0           15.6        359.0
# 21           2.0        4.0            8.8        202.0
# 22           2.0        4.0           10.0        230.0
# 23           2.0        4.0            9.3        214.0
# 24           2.0        4.0           10.0        230.0
# 25           2.0        4.0           10.0        230.0
# 26           2.0        4.0            9.3        214.0
# 27           2.0        4.0           10.2        235.0
# 28           3.0        6.0           10.9        251.0
# 29           3.0        6.0            8.3        224.0
# 30           3.0        6.0           11.2        258.0
# ...          ...        ...            ...          ...
# 1043         2.0        4.0            9.0        207.0
# 1044         2.0        4.0            9.0        207.0
# 1045         2.0        4.0            9.2        212.0
# 1046         2.0        4.0            6.9        186.0
# 1047         2.0        4.0            6.9        186.0
# 1048         1.4        4.0            5.4        124.0
# 1049         1.8        4.0            8.6        198.0
# 1050         1.8        4.0            8.6        198.0
# 1051         2.5        5.0            9.7        223.0
# 1052         2.5        5.0            9.8        225.0
# 1053         3.6        6.0           10.8        248.0
# 1054         2.0        4.0            7.1        192.0
# 1055         2.0        4.0            6.8        184.0
# 1056         3.6        6.0           12.1        278.0
# 1057         2.0        4.0           10.7        246.0
# 1058         2.0        4.0           11.6        267.0
# 1059         2.0        4.0           10.7        246.0
# 1060         3.6        6.0           12.2        281.0
# 1061         3.0        6.0           10.4        281.0
# 1062         2.5        5.0            9.7        223.0
# 1063         2.5        5.0           10.1        232.0
# 1064         3.0        6.0           11.5        264.0
# 1065         3.2        6.0           10.2        235.0
# 1066         3.0        6.0           11.5        264.0
# 1067         3.2        6.0           11.2        258.0
# 1068         3.0        6.0           11.8        271.0
# 1069         3.2        6.0           11.5        264.0
# 1070         3.0        6.0           11.8        271.0
# 1071         3.2        6.0           11.3        260.0
# 1072         3.2        6.0           12.8        294.0
#
# [1072 rows x 4 columns]

# %%
cdf1
# Out:
#      ENGINESIZE  CYLINDERS FUELConscityLper100km HWYLper100km COMbLper100km  \
# 1           2.0        4.0                   9.9          6.7           8.5
# 2           2.4        4.0                  11.2          7.7           9.6
# 3           1.5        4.0                   6.0          5.8           5.9
# 4           3.5        6.0                  12.7          9.1          11.1
# 5           3.5        6.0                  12.1          8.7          10.6
# 6           3.5        6.0                  11.9          7.7          10.0
# 7           3.5        6.0                  11.8          8.1          10.1
# 8           3.7        6.0                  12.8          9.0          11.1
# 9           3.7        6.0                  13.4          9.5          11.6
# 10          2.4        4.0                  10.6          7.5           9.2
# 11          2.4        4.0                  11.2          8.1           9.8
# 12          3.5        6.0                  12.1          8.3          10.4
# 13          1.8        4.0                   9.7          6.9           8.4
# 14          5.9       12.0                  18.0         12.6          15.6
# 15          5.9       12.0                  18.0         12.6          15.6
# 16          4.7        8.0                  17.4         11.3          14.7
# 17          4.7        8.0                  18.1         12.2          15.4
# 18          4.7        8.0                  17.4         11.3          14.7
# 19          4.7        8.0                  18.1         12.2          15.4
# 20          5.9       12.0                  18.0         12.6          15.6
# 21          2.0        4.0                   9.9          7.4           8.8
# 22          2.0        4.0                  11.5          8.1          10.0
# 23          2.0        4.0                  10.8          7.5           9.3
# 24          2.0        4.0                  11.5          8.1          10.0
# 25          2.0        4.0                  11.5          8.1          10.0
# 26          2.0        4.0                  10.8          7.5           9.3
# 27          2.0        4.0                  12.0          8.1          10.2
# 28          3.0        6.0                  12.8          8.6          10.9
# 29          3.0        6.0                   9.8          6.4           8.3
# 30          3.0        6.0                  13.1          8.8          11.2
# ...         ...        ...                   ...          ...           ...
# 1043        2.0        4.0                  10.4          7.2           9.0
# 1044        2.0        4.0                  10.2          7.5           9.0
# 1045        2.0        4.0                  10.6          7.4           9.2
# 1046        2.0        4.0                   7.9          5.7           6.9
# 1047        2.0        4.0                   7.9          5.6           6.9
# 1048        1.4        4.0                   5.6          5.2           5.4
# 1049        1.8        4.0                   9.9          6.9           8.6
# 1050        1.8        4.0                  10.0          6.9           8.6
# 1051        2.5        5.0                  11.0          8.0           9.7
# 1052        2.5        5.0                  11.4          7.8           9.8
# 1053        3.6        6.0                  12.4          8.8          10.8
# 1054        2.0        4.0                   8.1          5.9           7.1
# 1055        2.0        4.0                   8.0          5.4           6.8
# 1056        3.6        6.0                  14.2          9.5          12.1
# 1057        2.0        4.0                  11.7          9.5          10.7
# 1058        2.0        4.0                  13.6          9.2          11.6
# 1059        2.0        4.0                  11.7          9.4          10.7
# 1060        3.6        6.0                  13.8         10.3          12.2
# 1061        3.0        6.0                  12.3          8.0          10.4
# 1062        2.5        5.0                  11.3          7.8           9.7
# 1063        2.5        5.0                  11.6          8.3          10.1
# 1064        3.0        6.0                  13.2          9.5          11.5
# 1065        3.2        6.0                  11.9          8.1          10.2
# 1066        3.0        6.0                  13.2          9.5          11.5
# 1067        3.2        6.0                  13.0          8.9          11.2
# 1068        3.0        6.0                  13.4          9.8          11.8
# 1069        3.2        6.0                  13.2          9.5          11.5
# 1070        3.0        6.0                  13.4          9.8          11.8
# 1071        3.2        6.0                  12.9          9.3          11.3
# 1072        3.2        6.0                  14.9         10.2          12.8
#
#      CO2Emission
# 1            196
# 2            221
# 3            136
# 4            255
# 5            244
# 6            230
# 7            232
# 8            255
# 9            267
# 10           212
# 11           225
# 12           239
# 13           193
# 14           359
# 15           359
# 16           338
# 17           354
# 18           338
# 19           354
# 20           359
# 21           202
# 22           230
# 23           214
# 24           230
# 25           230
# 26           214
# 27           235
# 28           251
# 29           224
# 30           258
# ...          ...
# 1043         207
# 1044         207
# 1045         212
# 1046         186
# 1047         186
# 1048         124
# 1049         198
# 1050         198
# 1051         223
# 1052         225
# 1053         248
# 1054         192
# 1055         184
# 1056         278
# 1057         246
# 1058         267
# 1059         246
# 1060         281
# 1061         281
# 1062         223
# 1063         232
# 1064         264
# 1065         235
# 1066         264
# 1067         258
# 1068         271
# 1069         264
# 1070         271
# 1071         260
# 1072         294
#
# [1072 rows x 6 columns]

# %%
cdf1 = cdf1.astype(np.float)
plt.scatter(cdf1.ENGINESIZE, cdf1.CO2Emission,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %%
msk = np.random.rand(len(df)) < 0.8
train = cdf1[msk]
test = cdf1[~msk]

# %%
plt.scatter(train.ENGINESIZE, train.CO2Emission,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['ENGINESIZE','CYLINDERS','COMbLper100km']])
y = np.asanyarray(train[['CO2Emission']])
regr.fit (x, y)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [[10.1111599   7.99628646  9.57820199]]

# %%
y_hat= regr.predict(test[['ENGINESIZE','CYLINDERS','COMbLper100km']])
x = np.asanyarray(test[['ENGINESIZE','CYLINDERS','COMbLper100km']])
y = np.asanyarray(test[['CO2Emission']])
print("Residual sum of squares: %.2f"
      % np.mean((y_hat - y) ** 2))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(x, y))
# Out:
# Residual sum of squares: 463.90
# Variance score: 0.87

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['ENGINESIZE','CYLINDERS','FUELConscityLper100km']])
y = np.asanyarray(train[['CO2Emission']])
regr.fit (x, y)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [[10.62302795  6.77801292  8.41350874]]

# %%
y_hat= regr.predict(test[['ENGINESIZE','CYLINDERS','FUELConscityLper100km']])
x = np.asanyarray(test[['ENGINESIZE','CYLINDERS','FUELConscityLper100km']])
y = np.asanyarray(test[['CO2Emission']])
print("Residual sum of squares: %.2f"
      % np.mean((y_hat - y) ** 2))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(x, y))
# Out:
# Residual sum of squares: 488.76
# Variance score: 0.86

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['ENGINESIZE','CYLINDERS','HWYLper100km']])
y = np.asanyarray(train[['CO2Emission']])
regr.fit (x, y)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [[11.1078457   9.97980477 10.37799589]]

# %%
y_hat= regr.predict(test[['ENGINESIZE','CYLINDERS','HWYLper100km']])
x = np.asanyarray(test[['ENGINESIZE','CYLINDERS','HWYLper100km']])
y = np.asanyarray(test[['CO2Emission']])
print("Residual sum of squares: %.2f"
      % np.mean((y_hat - y) ** 2))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(x, y))
# Out:
# Residual sum of squares: 458.00
# Variance score: 0.87

# %%
import tkinter as tk 

root= tk.Tk() 
 
canvas1 = tk.Canvas(root, width = 1200, height = 450)
canvas1.pack()

# with sklearn
#Intercept_result = ('Intercept: ', regr.intercept_)
#label_Intercept = tk.Label(root, text=Intercept_result, justify = 'center')
#canvas1.create_window(260, 220, window=label_Intercept)

# with sklearn
Coefficients_result  = ('Coefficients: ', regr.coef_)
label_Coefficients = tk.Label(root, text=Coefficients_result, justify = 'center')
canvas1.create_window(260, 240, window=label_Coefficients)

# with statsmodels
#print_model = model.summary()
#label_model = tk.Label(root, text=print_model, justify = 'center', relief = 'solid', bg='LightSkyBlue1')
#canvas1.create_window(800, 220, window=label_model)


# New_Interest_Rate label and input box
label1 = tk.Label(root, text='Engine Size: ')
canvas1.create_window(100, 100, window=label1)

entry1 = tk.Entry (root) # create 1st entry box
canvas1.create_window(270, 100, window=entry1)

# New_Unemployment_Rate label and input box
label2 = tk.Label(root, text='Number of Cylinders: ')
canvas1.create_window(120, 120, window=label2)

entry2 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 120, window=entry2)

# New_Unemployment_Rate label and input box
label3 = tk.Label(root, text='Fuel Consumption: ')
canvas1.create_window(140, 140, window=label3)

entry3 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 140, window=entry3)


def values(): 
    global Engine_Size #our 1st input variable
    Engine_Size = float(entry1.get()) 
    
    global N_of_Cylinders #our 2nd input variable
    N_of_Cylinders = float(entry2.get()) 
    
    global Fuel_Consumption #our 3rd input variable
    Fuel_Consumption = float(entry3.get())
    
    Prediction_result  = ('Predicted CO2 Emission: ', regr.predict([[Engine_Size ,N_of_Cylinders,Fuel_Consumption]]))
    label_Prediction = tk.Label(root, text= Prediction_result, bg='orange')
    canvas1.create_window(260, 280, window=label_Prediction)
    
button1 = tk.Button (root, text='Predict CO2 Consumption',command=values, bg='orange') # button to call the 'values' command above 
canvas1.create_window(270, 180, window=button1)

root.mainloop()
